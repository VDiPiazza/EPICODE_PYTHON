# %% [markdown]
# # W10_D5_ ESERCIZI

# %% [markdown]
# ## ESERZIO 1 (3 PARTI)

# %%
import dotenv
import os
from sqlalchemy import create_engine
import pandas as pd

dotenv.load_dotenv(dotenv_path="C:/Users/VDIPIAZZA/Desktop/.env", override=True)

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

conn_string = "mysql+pymysql://" + username + ":" + password + "@" + host + "/" + dbname
db_engine = create_engine(conn_string)
query = "SELECT * FROM dimproduct"
df = pd.read_sql(sql=query, con=db_engine)

# %%
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
#Quanti dati ci sono in totale?
df.shape
# Out:
# (606, 36)

# %%
#Quali sono i metadati?
df.dtypes
# Out:
# ProductKey                        int64
# ProductAlternateKey              object
# ProductSubcategoryKey           float64
# WeightUnitMeasureCode            object
# SizeUnitMeasureCode              object
# EnglishProductName               object
# SpanishProductName               object
# FrenchProductName                object
# StandardCost                    float64
# FinishedGoodsFlag                 int64
# Color                            object
# SafetyStockLevel                  int64
# ReorderPoint                      int64
# ListPrice                       float64
# Size                             object
# SizeRange                        object
# Weight                          float64
# DaysToManufacture                 int64
# ProductLine                      object
# DealerPrice                     float64
# Class                            object
# Style                            object
# ModelName                        object
# ...

# %%
#Stampiamo il primo elemento
df.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
#Stampiamo l'ultimo elemento
df.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
#Riusciamo a stampare cinque elementi a caso?
df.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 115         116             LJ-9161                    NaN
# 570         571          BK-T18Y-58                    3.0
# 167         168             MT-1000                    NaN
# 174         175             PA-823Y                    NaN
# 510         511          FR-M63S-40                   12.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  \
# 115                  None                None
# 570                    LB                  CM
# 167                  None                None
# 174                  None                None
# 510                    LB                  CM
#
#                    EnglishProductName         SpanishProductName  \
# 115              Thin-Jam Lock Nut 11
# 570           Touring-3000 Yellow, 58  Paseo: 3000, amarilla, 58
# 167                 Metal Tread Plate
# 174                    Paint - Yellow
# 510  ML Mountain Frame-W - Silver, 40
#
# ...

# %%
#Quali sono i colori disponibili?
df["Color"].unique()
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
#In media quanto pesano i prodotti?
df["Weight"].mean()
# Out:
# 56.1932269503546

# %%
#Quanto pesa il più leggero?
df["Weight"].min()
# Out:
# 2.12

# %%
#Quanto pesa il più pesante?
df["Weight"].max()
# Out:
# 1050.0

# %%
#Quanti prodotti pesano più di 100 Kg?
pesanti = df[df["Weight"] > 100]
len(pesanti)
# Out:
# 28

# %%
#Quanto costano in media i prodotti (colonna DealerPrice)?
df["StandardCost"].mean()
# Out:
# 436.82307304785894

# %%
#Qual è il prezzo medio per i prodotti di colore blu?
blu = df[df["Color"] == "Blue"]
blu["StandardCost"].mean()
# Out:
# 527.5721428571429

# %%
#Qual è il prezzo medio per i prodotti di colore rosso o nero?
rosso_o_nero = df[(df["Color"] == "Red") | (df["Color"] == "Black")]
rosso_o_nero["StandardCost"].mean()
# Out:
# 537.4548437500001

# %%
#Qual è il prezzo massimo per i prodotti di taglia 42 e peso oltre i 10 Kg?
prodotti = df[(df["Size"] == "42") & (df["Weight"] > 10)]
prodotti["StandardCost"].max()
# Out:
# 1912.15

# %%
#Qual è il nome inglese e il costo di produzione (StandardCost) di tutti i prodotti di taglia 42, peso oltre i 10 Kg e colore argento?
tutto = df[(df["Size"] == "42") & (df["Weight"] > 10) & (df["Color"] == "Silver")]
tutto.loc[:, ["EnglishProductName", "Size", "StandardCost", "Weight", "Color"]]
# Out:
#             EnglishProductName Size  StandardCost  Weight   Color
# 344    Mountain-100 Silver, 42   42       1912.15   20.77  Silver
# 353    Mountain-200 Silver, 42   42       1117.86   23.77  Silver
# 354    Mountain-200 Silver, 42   42       1265.62   23.77  Silver
# 588  Mountain-400-W Silver, 42   42        419.78   27.13  Silver
# 591    Mountain-500 Silver, 42   42        308.22   27.77  Silver

# %%
#Esaminiamo la differenza tra lo StandardCost e il DealerPrice degli ultimi 20 elementi del dataset: c'è un pattern? C'è qualche elemento che non lo segue?

df.loc[:, ["StandardCost","DealerPrice"]].tail(20)
# Out:
#      StandardCost  DealerPrice
# 586        419.78      461.694
# 587        419.78      461.694
# 588        419.78      461.694
# 589        419.78      461.694
# 590        308.22      338.994
# 591        308.22      338.994
# 592        308.22      338.994
# 593        308.22      338.994
# 594        308.22      338.994
# 595        294.58      323.994
# 596        294.58      323.994
# 597        294.58      323.994
# 598        294.58      323.994
# 599        294.58      323.994
# 600         23.97       32.394
# 601         44.95       60.744
# 602         53.94       72.894
# 603        343.65      323.994
# 604        343.65      323.994
# 605        343.65      323.994

# %% [markdown]
# ## ESERCIZIO 2 (AMAZON)

# %%
amazon = pd.read_csv("C:/Users/VDIPIAZZA/Desktop/EPICODE CORSO/3. Python June 3rd - July 5th/beginner_datasets/amazon.csv")

# %%
#Valutiamo la dimensione del dataset
amazon.shape
# Out:
# (20000, 2)

# %%
#Visualizziamo dieci righe a caso
amazon.sample(10)
# Out:
#                                               reviewText  Positive
# 16005  The my scan feature saves previous scans and c...         1
# 14352  for the free simple version its what i expecte...         1
# 19595  Great tool to sit back and keep your mind conn...         1
# 13601  cute old style game easy to play.works well on...         1
# 10829  I watch this game all the time on tv, and was ...         1
# 9798   This app does not need to access my phone stat...         0
# 2549   Installed it so i could have a visual as well ...         0
# 4490   I like any kind of puzzle game.  I have done a...         1
# 13854  I like clean running, and basic types of games...         1
# 10079  I love this game on the kindle fire but on the...         0

# %%
#Osserviamo quali sono i nomi di colonna
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reviewText  20000 non-null  object
#  1   Positive    20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB

# %% [markdown]
# ## ESERCIZIO 3 (DIABETES)

# %%
diab = pd.read_csv("C:/Users/VDIPIAZZA/Desktop/EPICODE CORSO/3. Python June 3rd - July 5th/beginner_datasets/diabetes.csv")

# %%
#Osserviamone le dimensioni e un'anteprima di cinque righe; Prendiamoci un po' di tempo per dare un'occhiata ai metadati delle colonne;
diab.head(5)
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
#Stampiamo dei descrittori statistici del dataset
diab.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
#Selezioniamo i dati relativi a diverse fasce di età: <20, 20-30, 30-40, 40-50,>50

filtro20 = diab.loc[:, "Age (years)"] <= 20
diab.loc[filtro20, "Age (years)"]
# Out:
# Series([], Name: Age (years), dtype: int64)

# %%
filtro2030 = (diab.loc[:, "Age (years)"] >= 20) & (diab.loc[:, "Age (years)"] < 30)
diab.loc[filtro2030, "Age (years)"]
# Out:
# 3      21
# 6      26
# 7      29
# 20     27
# 23     29
#        ..
# 753    26
# 758    26
# 760    22
# 764    27
# 767    23
# Name: Age (years), Length: 396, dtype: int64

# %%
filtro3040 = (diab.loc[:, "Age (years)"] >= 30) & (diab.loc[:, "Age (years)"] < 40)
diab.loc[filtro3040, "Age (years)"]
# Out:
# 1      31
# 2      32
# 4      33
# 5      30
# 10     30
#        ..
# 748    36
# 755    37
# 756    39
# 762    33
# 765    30
# Name: Age (years), Length: 165, dtype: int64

# %%
filtro4050 = (diab.loc[:, "Age (years)"] >= 40) & (diab.loc[:, "Age (years)"] < 50)
diab.loc[filtro4050, "Age (years)"]
# Out:
# 22     41
# 25     41
# 26     43
# 34     45
# 37     46
#        ..
# 743    45
# 745    46
# 754    45
# 761    43
# 766    47
# Name: Age (years), Length: 118, dtype: int64

# %%
filtro50 = diab.loc[:, "Age (years)"] >= 50
diab.loc[filtro50, "Age (years)"]
# Out:
# 0      50
# 8      53
# 9      54
# 12     57
# 13     59
#        ..
# 734    53
# 749    50
# 757    52
# 759    66
# 763    63
# Name: Age (years), Length: 89, dtype: int64

# %%
#Qual è la media della pressione sanguigna diastolica per le diverse fasce di età?
"Diastolic blood pressure (mm Hg)"

filtro20 = diab.loc[:, "Age (years)"] <= 20
filtro2030 = (diab.loc[:, "Age (years)"] >= 20) & (diab.loc[:, "Age (years)"] < 30)
filtro4050 = (diab.loc[:, "Age (years)"] >= 40) & (diab.loc[:, "Age (years)"] < 50)
filtro50 = diab.loc[:, "Age (years)"] >= 50

# %%
#pressione20 
diab.loc[filtro20, "Diastolic blood pressure (mm Hg)"].mean()
# Out:
# nan

# %%
#pressione2030
diab.loc[filtro2030, "Diastolic blood pressure (mm Hg)"].mean()
# Out:
# 65.34848484848484

# %%
#pressione3040
diab.loc[filtro2030, "Diastolic blood pressure (mm Hg)"].mean()
# Out:
# 65.34848484848484

# %%
#pressione4050
diab.loc[filtro4050, "Diastolic blood pressure (mm Hg)"].mean()
# Out:
# 73.94067796610169

# %%
#pressione50
diab.loc[filtro50, "Diastolic blood pressure (mm Hg)"].mean()
# Out:
# 78.37078651685393

# %%
# Qual è la media della pressione per ogni singolo anno di età?
diab["Diastolic blood pressure (mm Hg)"].mean()
# Out:
# 69.10546875

# %% [markdown]
# ## ESERCIZIO 4 (INSURANCE)

# %%
ins = pd.read_csv("C:/Users/VDIPIAZZA/Desktop/EPICODE CORSO/3. Python June 3rd - July 5th/beginner_datasets/insurance.csv")

# %%
# Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna
ins.info()
ins.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Quali sono le medie di charges rispetto a region? Ci sono differenze significative?
ins.groupby("region")["charges"].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
#E rispetto a smoker? E a sex?
ins.groupby("smoker")["charges"].mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
ins.groupby("sex")["charges"].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
#Quali sono i descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?
ins["bmi"].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %% [markdown]
# ## ESERCIZIO 5 (POKEMON)

# %%
poke = pd.read_csv("C:/Users/VDIPIAZZA/Desktop/EPICODE CORSO/3. Python June 3rd - July 5th/beginner_datasets/pokemon.csv")

# %%
# Verifichiamo la dimensione, un'anteprima e osserviamo i nomi di colonna;
poke.info()
poke.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# ...

# %%
#È verosimile che la prima colonna dovrebbe essere un indice?
#• Confrontiamolo con l'indice messo automaticamente da Pandas: combaciano?
#• Se no, settare la prima colonna come indice. 
poke.set_index("#", inplace = True)

# %%
poke.info()
poke.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 75.8+ KB
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# ...

# %%
# Quali sono i Pokémon leggendari?
poke[poke["Legendary"]]
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144             Articuno       Ice    Flying    580   90      85      100
# 145               Zapdos  Electric    Flying    580   90      90       85
# 146              Moltres      Fire    Flying    580   90     100       90
# 150               Mewtwo   Psychic       NaN    680  106     110       90
# 150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..                   ...       ...       ...    ...  ...     ...      ...
# 719              Diancie      Rock     Fairy    600   50     100      150
# 719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 721            Volcanion      Fire     Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
# E quali sono i leggendari di tipo 1 Grass?
poke[(poke["Legendary"]) & (poke["Type 1"] == "Grass")]
# Out:
#                   Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 492  ShayminLand Forme  Grass       NaN    600  100     100      100      100
# 492   ShayminSky Forme  Grass    Flying    600  100     103       75      120
# 640           Virizion  Grass  Fighting    580   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 492      100    100           4       True
# 492       75    127           4       True
# 640      129    108           5       True

# %%
# E leggendari di tipo 1 Ice o Fire?
poke[(poke["Legendary"]) & ((poke["Type 1"] == "Ice") | (poke["Type 1"] == "Fire?"))]
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 144  Articuno    Ice  Flying    580  90      85      100       95      125
# 378    Regice    Ice     NaN    580  80      50      100      100      200
#
#      Speed  Generation  Legendary
# #
# 144     85           1       True
# 378     50           3       True

# %%
#Ordiniamo il dataset per la colonna Name;
poke.sort_values(by = "Name")
# Out:
#                         Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 460                Abomasnow    Grass     Ice    494   90      92       75
# 460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132      105
# 63                      Abra  Psychic     NaN    310   25      20       15
# 359                    Absol     Dark     NaN    465   65     130       60
# 359          AbsolMega Absol     Dark     NaN    565   65     150       60
# ..                       ...      ...     ...    ...  ...     ...      ...
# 571                  Zoroark     Dark     NaN    510   60     105       60
# 570                    Zorua     Dark     NaN    330   40      65       40
# 41                     Zubat   Poison  Flying    245   40      45       35
# 634                 Zweilous     Dark  Dragon    420   72      85       70
# 718         Zygarde50% Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
#Trasformiamo Name nell'indice
poke.set_index("Name", inplace = True)

# %%
#Quali sono i Pokémon della prima generazione con attacco > 50 e HP < 60?
poke[
(poke["Generation"] == 1) & 
(poke["Attack"] > 50) & 
(poke["HP"] < 60)
]
# Out:
#               Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Charmander      Fire     NaN    309  39      52       43       60       50
# Charmeleon      Fire     NaN    405  58      64       58       80       65
# Wartortle      Water     NaN    405  59      63       80       65       80
# Rattata       Normal     NaN    253  30      56       35       25       35
# Raticate      Normal     NaN    413  55      81       60       50       70
# Spearow       Normal  Flying    262  40      60       30       31       31
# Ekans         Poison     NaN    288  35      60       44       40       54
# Pikachu     Electric     NaN    320  35      55       40       50       50
# Sandshrew     Ground     NaN    300  50      75       85       20       30
# Nidoran♂      Poison     NaN    273  46      57       40       40       40
# Paras            Bug   Grass    285  35      70       55       45       55
# ...
